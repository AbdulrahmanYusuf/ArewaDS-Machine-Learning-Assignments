# %% [markdown]
# **Visualising Proportion**
#
# Let use a nature-focused dataset to visualize proportions. Let inspect to understand about the dataset

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
mushroom = pd.read_csv('../../ArewaDS-Machine-Learning-Assignments/week3/mushrooms.csv')
mushroom.tail()
# Out:
#           class cap-shape cap-surface cap-color     bruises   odor  \
# 8119     Edible   Knobbed      Smooth     Brown  No Bruises   None
# 8120     Edible    Convex      Smooth     Brown  No Bruises   None
# 8121     Edible      Flat      Smooth     Brown  No Bruises   None
# 8122  Poisonous   Knobbed       Scaly     Brown  No Bruises  Fishy
# 8123     Edible    Convex      Smooth     Brown  No Bruises   None
#
#      gill-attachment gill-spacing gill-size gill-color  ...  \
# 8119        Attached        Close     Broad     Yellow  ...
# 8120        Attached        Close     Broad     Yellow  ...
# 8121        Attached        Close     Broad      Brown  ...
# 8122            Free        Close    Narrow       Buff  ...
# 8123        Attached        Close     Broad     Yellow  ...
#
#      stalk-surface-below-ring stalk-color-above-ring stalk-color-below-ring  \
# 8119                   Smooth                 Orange                 Orange
# ...

# %% [markdown]
# To know the columns and the data types of the column

# %%
col = mushroom.select_dtypes(['object']).columns
col
# Out:
# Index(['class', 'cap-shape', 'cap-surface', 'cap-color', 'bruises', 'odor',
#        'gill-attachment', 'gill-spacing', 'gill-size', 'gill-color',
#        'stalk-shape', 'stalk-root', 'stalk-surface-above-ring',
#        'stalk-surface-below-ring', 'stalk-color-above-ring',
#        'stalk-color-below-ring', 'veil-type', 'veil-color', 'ring-number',
#        'ring-type', 'spore-print-color', 'population', 'habitat'],
#       dtype='object')

# %% [markdown]
# To know the number of entry in each column

# %%
print(mushroom.select_dtypes(['object']).count())
# Out:
# class                       8124
# cap-shape                   8124
# cap-surface                 8124
# cap-color                   8124
# bruises                     8124
# odor                        8124
# gill-attachment             8124
# gill-spacing                8124
# gill-size                   8124
# gill-color                  8124
# stalk-shape                 8124
# stalk-root                  8124
# stalk-surface-above-ring    8124
# stalk-surface-below-ring    8124
# stalk-color-above-ring      8124
# stalk-color-below-ring      8124
# veil-type                   8124
# veil-color                  8124
# ring-number                 8124
# ring-type                   8124
# spore-print-color           8124
# population                  8124
# habitat                     8124
# dtype: int64

# %% [markdown]
# Let consider a column *odour* to make a onversion and draw a pie-chart

# %%
smellclass=mushroom.groupby(['odor']).count()
smellclass
# Out:
#           class  cap-shape  cap-surface  cap-color  bruises  gill-attachment  \
# odor
# Almond      400        400          400        400      400              400
# Anise       400        400          400        400      400              400
# Creosote    192        192          192        192      192              192
# Fishy       576        576          576        576      576              576
# Foul       2160       2160         2160       2160     2160             2160
# Musty        36         36           36         36       36               36
# None       3528       3528         3528       3528     3528             3528
# Pungent     256        256          256        256      256              256
# Spicy       576        576          576        576      576              576
#
#           gill-spacing  gill-size  gill-color  stalk-shape  ...  \
# odor                                                        ...
# ...

# %%
lebel=['Almnd', 'Anise', 'Creosote', 'Fishy', 'Foul', 'Musty', 'None', 'Pungent', 'Spicy']
plt.pie(smellclass['population'], labels=lebel, autopct='%.1f %%')
plt.title('Fig. 1: Mushrooms Classification Based on Odour')
plt.show()

# %% [markdown]
# **Donuts**
#
# Is just a sub-class of pie-chart

# %% [markdown]
# Take a look at the various population of different type of mushrooms

# %%
Population=mushroom.groupby(['population']).count()
Population
# Out:
#             class  cap-shape  cap-surface  cap-color  bruises  odor  \
# population
# Abundant      384        384          384        384      384   384
# Clustered     340        340          340        340      340   340
# Numerous      400        400          400        400      400   400
# Scattered    1248       1248         1248       1248     1248  1248
# Several      4040       4040         4040       4040     4040  4040
# Solitary     1712       1712         1712       1712     1712  1712
#
#             gill-attachment  gill-spacing  gill-size  gill-color  ...  \
# population                                                        ...
# Abundant                384           384        384         384  ...
# Clustered               340           340        340         340  ...
# Numerous                400           400        400         400  ...
# Scattered              1248          1248       1248        1248  ...
# ...

# %%
import seaborn as sns
mushroom1 = mushroom[(mushroom['odor'] == 'Fishy') | (mushroom['odor'] == 'Foul') | (mushroom['odor'] == 'None')]
top = mushroom1['odor'].value_counts()
plt.figure(figsize=(10,7))
sns.barplot(x=top.index,y=top.values)
plt.xticks(rotation=45)
plt.title('Top genres',color = 'blue')
# Out:
# Text(0.5, 1.0, 'Top genres')

# %%
sns.FacetGrid(top, hue="population", height=4, aspect= 1.2) \
   .map(plt.scatter, "cap-color", "bruises") \
   .add_legend()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\Abdulrahman Yusuf\miniconda3\envs\dscience\lib\site-packages\pandas\core\indexes\base.py:3802, in Index.get_loc(self, key, method, tolerance)
#    3801 try:
# -> 3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
#
# File c:\Users\Abdulrahman Yusuf\miniconda3\envs\dscience\lib\site-packages\pandas\_libs\index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File c:\Users\Abdulrahman Yusuf\miniconda3\envs\dscience\lib\site-packages\pandas\_libs\index.pyx:165, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5745, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5753, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'population'
#
# ...

# %% [markdown]
# Here, we grouped that databy population. There are five listed different population, so use those as labels for the donut chart:

# %%
labels=['Abundant','Clustered','Numerous','Scattered','Several','Solitary']

plt.pie(Population['odor'], labels=labels,
        autopct='%1.1f%%', pctdistance=0.85)

  
center_circle = plt.Circle((0, 0), 0.30, fc='white')
fig = plt.gcf()

fig.gca().add_artist(center_circle)
  
plt.title('Fig. 2: Mushroom Population Odor')
  
plt.show()

# %% [markdown]
# This code instruct to draw a chart and a center circle, then adds that center circle in the chart. you can change the width of the center circle by changing 0.30 to another value.
#
# Donut charts can be tweaked in several ways to change the labels. The labels in particular can be highlighted for readability. you can learn more in the documentation.

# %%
labels=['Almnd', 'Anise', 'Creosote', 'Fishy', 'Foul', 'Musty', 'None', 'Pungent', 'Spicy']



# Create a figure and a subplot
fig, ax = plt.subplots()

# Create a scatter plot of the data
ax.scatter(smellclass['class'], smellclass.index, color='red')

# Draw vertical lines from the scatter points to the x-axis
ax.vlines(smellclass['class'], ymin=smellclass.index, ymax=-1, color='red')

# Set the y-axis ticks and labels
ax.set_yticks(smellclass.index)
ax.set_yticklabels(smellclass['class'])

# Set the axis labels
ax.set_xlabel('Class')
ax.set_ylabel('Labels')

# Set the title
plt.title('Fig. 3: Vline chart for Mushroom  Odor')

# Display the chart
plt.show()

# %% [markdown]
# Waffle

# %%
from pywaffle import Waffle
capcolor=mushroom.groupby(['cap-color']).count()  
data ={'color': ['brown', 'buff', 'cinnamon', 'green', 'pink', 'purple', 'red', 'white', 'yellow'],
    'amount': capcolor['class']
     }
  
df = pd.DataFrame(data)
  
fig = plt.figure(
    FigureClass = Waffle,
    rows = 100,
    values = df.amount,
    labels = list(df.color),
    figsize = (30,30),
    colors=["brown", "tan", "maroon", "green", "pink", "purple", "red", "whitesmoke", "yellow"]
)
# Out:
# C:\Users\Abdulrahman Yusuf\AppData\Roaming\Python\Python310\site-packages\IPython\core\events.py:89: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
#   func(*args, **kwargs)
# C:\Users\Abdulrahman Yusuf\AppData\Roaming\Python\Python310\site-packages\IPython\core\pylabtools.py:152: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
#   fig.canvas.print_figure(bytes_io, **kw)
# <Waffle size 3000x3000 with 1 Axes>

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
path = '../../ArewaDS-Machine-Learning-Assignments/week2/form.csv'
form_df = pd.read_csv(path)
form_df
# Out:
#   birth_month       State   Pet
# 0     January         NaN  Cats
# 1         JAN          CA  Cats
# 2        Sept       Hawai   Dog
# 3     january          AK   Dog
# 4      July            RI  Cats
# 5  September   California  Cats
# 6  April               CA   Dog
# 7     January  California  Cats
# 8   November           FL   Dog
# 9   December      Florida  Cats

# %%
form_df['State'].value_counts().plot(kind='bar')
plt.show()

# %% [markdown]
# let check consistency about the birth month

# %%
k = form_df.value_counts(form_df['birth_month'].values) 
plt.title('Barchart show the bith month')
plt.ylabel('No of monthe')
plt.xlabel('Months')
k.plot(kind='bar')
plt.show()

# %%
form_df['birth_month'].value_counts().plot(kind='bar');
plt.show()

# %% [markdown]
# It can be observed that the month January has been etered using different pattern. therefore inconsistent

# %% [markdown]
# Null Value detection

# %%
form_df.isnull().sum()
# Out:
# birth_month    0
# State          1
# Pet            0
# dtype: int64

# %% [markdown]
# Drop Null column

# %%
form_df.dropna()
# Out:
#   birth_month       State   Pet
# 1         JAN          CA  Cats
# 2        Sept       Hawai   Dog
# 3     january          AK   Dog
# 4      July            RI  Cats
# 5  September   California  Cats
# 6  April               CA   Dog
# 7     January  California  Cats
# 8   November           FL   Dog
# 9   December      Florida  Cats

# %%
for i in form_df['birth_month']:
    k = print(i.upper())
    form_df['birth_months'] = form_df[k]
# Out:
# JANUARY
# JAN
# SEPT
# JANUARY
# JULY
# SEPTEMBER
# APRIL
# JANUARY
# NOVEMBER
# DECEMBER
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\Abdulrahman Yusuf\miniconda3\envs\dscience\lib\site-packages\pandas\core\indexes\base.py:3802, in Index.get_loc(self, key, method, tolerance)
#    3801 try:
# -> 3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
#
# File c:\Users\Abdulrahman Yusuf\miniconda3\envs\dscience\lib\site-packages\pandas\_libs\index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File c:\Users\Abdulrahman Yusuf\miniconda3\envs\dscience\lib\site-packages\pandas\_libs\index.pyx:165, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5745, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# ...

# %%
state_count = form_df.value_counts(form_df['State'].values)
state_count
# Out:
# CA            2
# California    2
# AK            1
# FL            1
# Florida       1
# Hawai         1
# RI            1
# dtype: int64

# %% [markdown]
# Fill null value with an entry before the empty cell using 'bfill' method. Therefore, the null in first row of state column is fill with CA which is the entry of second raw

# %%
form_df.fillna(method='bfill')
# Out:
#   birth_month       State   Pet
# 0     January          CA  Cats
# 1         JAN          CA  Cats
# 2        Sept       Hawai   Dog
# 3     january          AK   Dog
# 4      July            RI  Cats
# 5  September   California  Cats
# 6  April               CA   Dog
# 7     January  California  Cats
# 8   November           FL   Dog
# 9   December      Florida  Cats

# %% [markdown]
# Find douplicate if any

# %%
form_df.duplicated()
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# 5    False
# 6    False
# 7    False
# 8    False
# 9    False
# dtype: bool

# %%
form_df['birth_month'].dtype
# Out:
# dtype('O')

# %%
mask = pd.to_datetime(form_df['birth_month'], format='%B', errors='coerce').notna()
form_df.loc[:, mask]

# %% [markdown]
# date parsing

# %%
form_df['date_parsed'] = pd.to_datetime(form_df['birth_month'], format=None)
